# %% [markdown]
# OS

# %%
os.getcwd()
# Out:
# 'c:\\Users\\HP PC\\Python_JUN_2022'

# %%
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  'Basics',
#  'basics.ipynb',
#  'example.py',
#  'example2.py',
#  'example4.py',
#  'example5.py',
#  'example6.py',
#  'exmple.py',
#  'file_handling.ipynb',
#  'info.txt',
#  'Kahani.txt',
#  'list.ipynb',
#  'loop.ipynb',
#  'loops.ipynb',
#  'Medical_Physics.ipynb',
#  'nicorn225.ipynb',
#  'OS_Module.ipynb',
#  'strings_qus.ipynb']

# %%
files = os.listdir()
print(files)
# Out:
# ['.git', '.gitattributes', '.gitignore', 'Basics', 'basics.ipynb', 'example.py', 'example2.py', 'example4.py', 'example5.py', 'example6.py', 'exmple.py', 'file_handling.ipynb', 'info.txt', 'Kahani.txt', 'list.ipynb', 'loop.ipynb', 'loops.ipynb', 'Medical_Physics.ipynb', 'nicorn225.ipynb', 'OS_Module.ipynb', 'strings_qus.ipynb']

# %%
filesX = os.listdir("C:\XYZ")
print(filesX)
# Out:
# ['A', 'B', 'C', 'D']

# %%
len(filesX)
# Out:
# 4

# %%
filesX = os.listdir('C:/Windows/System32')

# %%
dlls = 0        #loop for find dll in entire folder
for file in filesX:
    if file.endswith('.dll'):
        dlls += 1
print(f'the system has {dlls} dlls')
# Out:
# the system has 3070 dlls

# %%
os.mkdir('Basics')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# c:\Users\HP PC\Python_JUN_2022\OS_Module.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP%20PC/Python_JUN_2022/OS_Module.ipynb#ch0000011?line=0'>1</a> os.mkdir('Basics')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Basics'

# %%
os.mkdir('Faltu_Folder')

# %%
os.rmdir('Faltu_Folder')

# %%
os.path.isdir('ghjgdh')
# Out:
# False

# %%
os.path.isdir('Basics')
# Out:
# True

# %%
for item in file:
    if os.path.isdir(item):
        print(f'{item} is Directory')
# Out:
# . is Directory

# %%
os.mkdir('Basics001')       #for open new folder

# %%
sizeoFV = os.path.getsize(r"C:\Ram\My Library\RSO\3.__Physics_in_Radiation_oncology__www.myuptodate.com_.pdf")

# %%
print(sizeoFV)
# Out:
# 3957593

# %%
sizeoFV/1024        # size in Kb
# Out:
# 3864.8369140625

# %%
sizeoFV/(1024*1024)     # size in Mb
# Out:
# 3.77425479888916

# %%
files = os.listdir()
for item in files:
    if os.path.isfile(item):
        sz = os.path.getsize(item)
        print(f'{item.ljust(25)} | {sz/1024 :.1f} kb')
# Out:
# .gitattributes            | 0.1 kb
# .gitignore                | 2.8 kb
# basics.ipynb              | 27.4 kb
# example.py                | 0.2 kb
# example2.py               | 0.1 kb
# example4.py               | 0.2 kb
# example5.py               | 0.2 kb
# example6.py               | 0.3 kb
# exmple.py                 | 0.2 kb
# file_handling.ipynb       | 153.9 kb
# info.txt                  | 0.0 kb
# Kahani.txt                | 0.1 kb
# list.ipynb                | 9.3 kb
# loop.ipynb                | 22.3 kb
# loops.ipynb               | 28.6 kb
# Medical_Physics.ipynb     | 2.4 kb
# nicorn225.ipynb           | 2.2 kb
# OS_Module.ipynb           | 9.9 kb
# strings_qus.ipynb         | 61.3 kb

# %%
folder = 'C:/Windows/System32/'
files = os.listdir(folder)
for item in files:
    fullpath = os.path.join(folder,item)
    if os.path.isfile(fullpath):
        print(f'{item.ljust(70)} | {sz/1024:.2f} kb')
# Out:
# 0ae3b998-9a38-4b72-a4c4-06849441518d_Servicing-Stack.dll               | 61.29 kb
# 69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice.dll               | 61.29 kb
# 6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall.dll          | 61.29 kb
# @AdvancedKeySettingsNotification.png                                   | 61.29 kb
# @AppHelpToast.png                                                      | 61.29 kb
# @AudioToastIcon.png                                                    | 61.29 kb
# @BackgroundAccessToastIcon.png                                         | 61.29 kb
# @bitlockertoastimage.png                                               | 61.29 kb
# @edptoastimage.png                                                     | 61.29 kb
# @EnrollmentToastIcon.png                                               | 61.29 kb
# @language_notification_icon.png                                        | 61.29 kb
# ...

# %%
data = ""
folder = 'C:/Windows/System32/'
files = os.listdir(folder)
for item in files:
    fullpath = os.path.join(folder,item)
    if os.path.isfile(fullpath):
        print(f'{item.ljust(70)} | {sz/1024:.2f} kb')
        out = f'{item.ljust(70)} | {sz/1024:.2f} kb'
        print(out)
        data += out + '\n'
# Out:
# 0ae3b998-9a38-4b72-a4c4-06849441518d_Servicing-Stack.dll               | 61.29 kb
# 0ae3b998-9a38-4b72-a4c4-06849441518d_Servicing-Stack.dll               | 61.29 kb
# 69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice.dll               | 61.29 kb
# 69fe178f-26e7-43a9-aa7d-2b616b672dde_eventlogservice.dll               | 61.29 kb
# 6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall.dll          | 61.29 kb
# 6bea57fb-8dfb-4177-9ae8-42e8b3529933_RuntimeDeviceInstall.dll          | 61.29 kb
# @AdvancedKeySettingsNotification.png                                   | 61.29 kb
# @AdvancedKeySettingsNotification.png                                   | 61.29 kb
# @AppHelpToast.png                                                      | 61.29 kb
# @AppHelpToast.png                                                      | 61.29 kb
# @AudioToastIcon.png                                                    | 61.29 kb
# ...

# %%
from dputils import files

# %%
files.save_data('dlls.txt', data)
# Out:
# True
